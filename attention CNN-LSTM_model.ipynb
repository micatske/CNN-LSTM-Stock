# %%
import numpy as np
import pandas as pd
import os
from datetime import datetime

# %%
import tensorflow as tf
print(tf. __version__)
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2.9.2
# Num GPUs Available:  1

# %%
import math
import seaborn as sns
import datetime as dt
from datetime import datetime    
sns.set_style("whitegrid")
from pandas.plotting import autocorrelation_plot
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")

# %%
dir="data/"

# %%
df=pd.read_csv(dir+"GOOG.csv")  # read the data
df.head()  # print the summary of the data
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2017-09-01  47.056499  47.124001  46.757500  46.867001  46.867001  18948000
# 1  2017-09-05  46.653999  46.849998  46.098000  46.422501  46.422501  26528000
# 2  2017-09-06  46.507500  46.545750  45.963501  46.390499  46.390499  30554000
# 3  2017-09-07  46.586498  46.820499  46.181000  46.797501  46.797501  24254000
# 4  2017-09-08  46.824501  46.849499  46.243999  46.325001  46.325001  20230000

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean     82.767391    83.667386    81.913428    82.806675    82.806675
# std      32.311184    32.633284    31.948660    32.277134    32.277134
# min      45.870998    46.104000    45.485001    45.750000    45.750000
# 25%      56.346373    57.056126    55.833039    56.491998    56.491998
# 50%      67.585751    68.242001    67.174499    67.612747    67.612747
# 75%     113.282623   114.807499   112.140499   113.340628   113.340628
# max     151.863495   152.100006   149.887497   150.709000   150.709000
#
#              Volume
# count  1.258000e+03
# mean   3.102087e+07
# std    1.359313e+07
# min    6.936000e+06
# 25%    2.251200e+07
# 50%    2.783600e+07
# 75%    3.531300e+07
# max    1.241400e+08

# %%
df.isnull().sum().sum()  # check if there is any missing value
# Out:
# 0

# %%
df.plot(legend=True,subplots=True, figsize=(10,10))  # plot the data
plt.show()

# %%
##Close Price

# %%
from sklearn.model_selection import train_test_split

X_close=[]
Y_close=[]
window_size=100

for i in range(1,len(df)-window_size):
    first=df.iloc[i,3]
    temp=[]
    temp2=[]
    for j in range(window_size):
        temp.append((df.iloc[i+j,3]-first)/first)
    temp2.append((df.iloc[i+window_size,3]-first)/first)
    X_close.append(np.array(temp).reshape(window_size,1))
    Y_close.append(np.array(temp2).reshape(1,1))

# %%
import tensorflow as tf

# %%
x_close_train, x_close_test, y_close_train, y_close_test = train_test_split(X_close, Y_close, test_size=0.2, random_state=42,shuffle=True)
x_close_train, x_close_test, y_close_train, y_close_test=np.array(x_close_train),np.array(x_close_test),np.array(y_close_train),np.array(y_close_test)
x_close_train=x_close_train.reshape(x_close_train.shape[0],1,window_size,1)
x_close_test=x_close_test.reshape(x_close_test.shape[0],1,window_size,1)

# %%
x_close_train.shape
# Out:
# (925, 1, 100, 1)

# %%
len(x_close_train)
# Out:
# 925

# %%
##Train the model

# %%
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Bidirectional, TimeDistributed,Multiply,Permute
from tensorflow.keras.layers import MaxPooling1D, Flatten
from tensorflow.keras.regularizers import L1, L2
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.metrics import RootMeanSquaredError
import pydot
from tensorflow.keras.models import Model

# %%
from tensorflow.keras.utils import plot_model
import pydot

# %%
def attention_3d(inputs,single_attention_vector = False):
    input_dim = int(inputs.shape[2])
    a = inputs
    # a = Permute((2, 1))(inputs)
    # a = Reshape((input_dim, TIME_STEPS))(a) # this line is not useful. It's just to know which dimension is what.
    a = Dense(input_dim, activation='softmax')(a)
    if single_attention_vector:
        a = Lambda(lambda x: K.mean(x, axis=1), name='dim_reduction')(a)
        a = RepeatVector(input_dim)(a)
    a_probs = Permute((1, 2), name='attention_vec')(a)

    output_attention_mul = Multiply()([inputs, a_probs])
    return output_attention_mul

# %%
def build_model():
    input_layer= tf.keras.Input(shape=(None,100, 1))
    
    #cov layers
    cov_1=TimeDistributed(Conv1D(64, kernel_size=3, activation='relu'))(input_layer)
    pool_1=TimeDistributed(MaxPooling1D(2))(cov_1)
    cov_2=TimeDistributed(Conv1D(128, kernel_size=3, activation='relu'))(pool_1)
    pool_2=TimeDistributed(MaxPooling1D(2))(cov_2)
    cov_3=TimeDistributed(Conv1D(64, kernel_size=3, activation='relu'))(pool_2)
    pool_3=TimeDistributed(MaxPooling1D(2))(cov_3)
    flat=TimeDistributed(Flatten())(pool_3)
    
     #attention
    attention_mul = attention_3d(flat)
    #attention_mul = Flatten()(attention_mul)
    
    
    #lstm layers    
    lstm_1=Bidirectional(LSTM(100, return_sequences=True))(attention_mul)
    drop_1=Dropout(0.5)(lstm_1)
    lstm_2=Bidirectional(LSTM(100, return_sequences=False))(drop_1)
    drop_2=Dropout(0.5)(lstm_2)
    
    
   
    output_layer=Dense(1, activation='linear')(drop_2)
    
    func_model = Model(inputs=input_layer, outputs=output_layer)
    
    return func_model

# %%
model = build_model()

# %%
plot_model(model, show_shapes=True, show_layer_names=True,to_file='model.png')

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# %%
model.compile(optimizer=optimizer, loss='mse', metrics=['mse', 'mae'])

# %%
history = model.fit(x_close_train, y_close_train, validation_data=(x_close_test,y_close_test), epochs=50,batch_size=40, verbose=1, shuffle =True)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 6s 61ms/step - loss: 0.0278 - mse: 0.0278 - mae: 0.1367 - val_loss: 0.0235 - val_mse: 0.0235 - val_mae: 0.1242
# Epoch 2/50
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0261 - mse: 0.0261 - mae: 0.1338 - val_loss: 0.0232 - val_mse: 0.0232 - val_mae: 0.1233
# Epoch 3/50
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0249 - mse: 0.0249 - mae: 0.1308 - val_loss: 0.0181 - val_mse: 0.0181 - val_mae: 0.1072
# Epoch 4/50
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0111 - mse: 0.0111 - mae: 0.0829 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0616
# Epoch 5/50
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0602 - val_loss: 0.0063 - val_mse: 0.0063 - val_mae: 0.0589
# Epoch 6/50
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0052 - mse: 0.0052 - mae: 0.0553 - val_loss: 0.0060 - val_mse: 0.0060 - val_mae: 0.0549
# Epoch 7/50
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0049 - mse: 0.0049 - mae: 0.0535 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0531
# Epoch 8/50
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0506 - val_loss: 0.0046 - val_mse: 0.0046 - val_mae: 0.0499
# Epoch 9/50
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0499 - val_loss: 0.0044 - val_mse: 0.0044 - val_mae: 0.0500
# Epoch 10/50
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0490 - val_loss: 0.0042 - val_mse: 0.0042 - val_mae: 0.0471
# Epoch 11/50
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0492 - val_loss: 0.0042 - val_mse: 0.0042 - val_mae: 0.0461
# Epoch 12/50
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0466 - val_loss: 0.0042 - val_mse: 0.0042 - val_mae: 0.0479
# Epoch 13/50
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0485 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0446
# Epoch 14/50
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0477 - val_loss: 0.0040 - val_mse: 0.0040 - val_mae: 0.0463
# Epoch 15/50
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0436 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0423
# Epoch 16/50
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0457 - val_loss: 0.0035 - val_mse: 0.0035 - val_mae: 0.0443
# Epoch 17/50
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0446 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0413
# Epoch 18/50
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0438 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0414
# Epoch 19/50
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0430 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0432
# Epoch 20/50
# 24/24 [==============================] - 0s 21ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0428 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0421
# Epoch 21/50
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0423 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0410
# Epoch 22/50
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0420 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0421
# Epoch 23/50
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0417 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0411
# Epoch 24/50
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0395 - val_loss: 0.0027 - val_mse: 0.0027 - val_mae: 0.0398
# Epoch 25/50
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0389 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0416
# Epoch 26/50
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0404 - val_loss: 0.0027 - val_mse: 0.0027 - val_mae: 0.0387
# Epoch 27/50
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0397 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0386
# Epoch 28/50
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0392 - val_loss: 0.0025 - val_mse: 0.0025 - val_mae: 0.0381
# Epoch 29/50
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0404 - val_loss: 0.0025 - val_mse: 0.0025 - val_mae: 0.0378
# Epoch 30/50
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0387 - val_loss: 0.0027 - val_mse: 0.0027 - val_mae: 0.0388
# Epoch 31/50
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0378 - val_loss: 0.0023 - val_mse: 0.0023 - val_mae: 0.0361
# Epoch 32/50
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0381 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0400
# Epoch 33/50
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0372 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0389
# Epoch 34/50
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0357 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0346
# Epoch 35/50
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0358 - val_loss: 0.0023 - val_mse: 0.0023 - val_mae: 0.0353
# Epoch 36/50
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0347 - val_loss: 0.0023 - val_mse: 0.0023 - val_mae: 0.0360
# Epoch 37/50
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0343 - val_loss: 0.0023 - val_mse: 0.0023 - val_mae: 0.0351
# Epoch 38/50
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0356 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0423
# Epoch 39/50
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0340 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0335
# Epoch 40/50
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0345 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0336
# Epoch 41/50
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0354 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0355
# Epoch 42/50
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0335 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0326
# Epoch 43/50
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0331 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0341
# Epoch 44/50
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0356 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0320
# Epoch 45/50
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0312 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0326
# Epoch 46/50
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0310 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0324
# Epoch 47/50
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0329 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0304
# Epoch 48/50
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0304 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0320
# Epoch 49/50
# 24/24 [==============================] - 0s 21ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0318 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0324
# Epoch 50/50
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0317 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0309

# %%
predicted=model.predict(x_close_test)
# Out:
# 8/8 [==============================] - 1s 15ms/step

# %%
predicted
# Out:
# array([[ 0.11986767],
#        [-0.05367034],
#        [ 0.13196291],
#        [ 0.14743325],
#        [ 0.11827533],
#        [ 0.09162684],
#        [ 0.28964943],
#        [-0.1265037 ],
#        [ 0.15350507],
#        [-0.02393625],
#        [ 0.0232455 ],
#        [ 0.1915316 ],
#        [ 0.23956096],
#        [ 0.22475873],
#        [ 0.07361604],
#        [-0.15301137],
#        [ 0.3254662 ],
#        [ 0.15247639],
#        [ 0.10821167],
#        [ 0.11753286],
#        [-0.06324577],
#        [ 0.14512248],
#        [ 0.01661223],
#        [-0.11741073],
#        [ 0.08996563],
#        [ 0.01420341],
#        [ 0.12947232],
#        [ 0.170458  ],
#        [ 0.24769232],
#        [-0.14122556],
#        [ 0.18596633],
#        [ 0.16607586],
#        [-0.00598883],
#        [ 0.0380042 ],
#        [ 0.25954485],
#        [ 0.14562416],
#        [-0.20536943],
#        [-0.10801345],
#        [ 0.34041426],
#        [-0.00113579],
#        [ 0.17617597],
#        [-0.21784328],
#        [-0.09309901],
#        [ 0.4048127 ],
#        [ 0.05178672],
#        [ 0.15884054],
#        [ 0.29469794],
#        [ 0.2652109 ],
#        [ 0.1413135 ],
#        [ 0.0823973 ],
#        [ 0.01675135],
#        [ 0.07590263],
#        [ 0.14233108],
#        [ 0.02103985],
#        [-0.19212943],
#        [ 0.4011973 ],
#        [ 0.0816018 ],
#        [ 0.1785607 ],
#        [ 0.0007436 ],
#        [ 0.0832123 ],
#        [ 0.02184753],
#        [-0.17842838],
#        [-0.10496005],
#        [-0.06305285],
#        [ 0.17973801],
#        [ 0.09898785],
#        [-0.00259095],
#        [ 0.3601648 ],
#        [ 0.20964713],
#        [ 0.16349028],
#        [-0.11546758],
#        [ 0.17026685],
#        [ 0.30408993],
#        [ 0.03793948],
#        [ 0.01394833],
#        [ 0.23324586],
#        [ 0.27389973],
#        [ 0.36035964],
#        [ 0.1321896 ],
#        [-0.01198971],
#        [ 0.126862  ],
#        [-0.17849714],
#        [ 0.01909995],
#        [ 0.08247121],
#        [ 0.3801823 ],
#        [ 0.31153327],
#        [ 0.11836976],
#        [-0.14897846],
#        [ 0.16996339],
#        [ 0.17459174],
#        [ 0.08028348],
#        [ 0.19604276],
#        [-0.11133994],
#        [-0.04989238],
#        [ 0.16288048],
#        [ 0.16381514],
#        [-0.04634456],
#        [-0.02919193],
#        [-0.00873739],
#        [-0.02327527],
#        [-0.14576203],
#        [-0.00630943],
#        [ 0.06972364],
#        [ 0.11434807],
#        [ 0.1603101 ],
#        [ 0.13734196],
#        [ 0.3309044 ],
#        [ 0.02445114],
#        [-0.04848951],
#        [-0.02766736],
#        [ 0.22096975],
#        [ 0.22585198],
#        [-0.1764791 ],
#        [-0.14053458],
#        [ 0.039614  ],
#        [ 0.05210301],
#        [ 0.2214904 ],
#        [ 0.10347196],
#        [-0.18925561],
#        [-0.18209185],
#        [ 0.03934328],
#        [ 0.35480195],
#        [-0.00089498],
#        [ 0.01205485],
#        [ 0.01782171],
#        [-0.10531522],
#        [ 0.10584132],
#        [-0.21567212],
#        [ 0.11651905],
#        [ 0.13656294],
#        [ 0.1715798 ],
#        [ 0.30189553],
#        [ 0.3121573 ],
#        [ 0.02210969],
#        [ 0.00068277],
#        [-0.06074122],
#        [ 0.08178   ],
#        [ 0.17267083],
#        [ 0.36511996],
#        [-0.06787443],
#        [ 0.30746803],
#        [ 0.12377191],
#        [-0.07181489],
#        [ 0.29628015],
#        [ 0.17596607],
#        [ 0.3600517 ],
#        [ 0.03781999],
#        [ 0.17194472],
#        [ 0.20173603],
#        [ 0.19352213],
#        [ 0.24323902],
#        [ 0.3604041 ],
#        [ 0.21261145],
#        [-0.1578021 ],
#        [ 0.391231  ],
#        [ 0.17223407],
#        [ 0.00995809],
#        [ 0.28320277],
#        [-0.06239605],
#        [-0.04773428],
#        [-0.07684329],
#        [-0.00763077],
#        [-0.09245691],
#        [-0.13427672],
#        [-0.21440841],
#        [ 0.2562213 ],
#        [ 0.17738365],
#        [ 0.00652692],
#        [ 0.12006782],
#        [ 0.2321396 ],
#        [ 0.40159243],
#        [ 0.12820128],
#        [ 0.3977679 ],
#        [ 0.28789622],
#        [ 0.20968586],
#        [ 0.31109276],
#        [-0.07977112],
#        [ 0.01746786],
#        [ 0.25301698],
#        [-0.08362593],
#        [-0.1884385 ],
#        [ 0.11043352],
#        [ 0.2045391 ],
#        [-0.11161287],
#        [ 0.07616719],
#        [ 0.03861124],
#        [ 0.17344642],
#        [ 0.02645166],
#        [-0.06901909],
#        [ 0.11181936],
#        [ 0.13769813],
#        [ 0.11632419],
#        [ 0.18185909],
#        [ 0.1579494 ],
#        [ 0.1044517 ],
#        [ 0.09418055],
#        [ 0.0485362 ],
#        [-0.14239135],
#        [ 0.3460842 ],
#        [-0.00647453],
#        [ 0.12220599],
#        [-0.00182959],
#        [-0.14538544],
#        [-0.14537218],
#        [-0.01416157],
#        [ 0.07055075],
#        [-0.11080484],
#        [ 0.3862238 ],
#        [-0.03100316],
#        [ 0.16316135],
#        [ 0.36881623],
#        [ 0.1559743 ],
#        [ 0.02918108],
#        [ 0.35207564],
#        [ 0.02442004],
#        [-0.01042437],
#        [ 0.35333717],
#        [-0.00443141],
#        [ 0.03084258],
#        [-0.06027499],
#        [ 0.19588952],
#        [ 0.10647009],
#        [-0.07202631],
#        [ 0.06870146],
#        [-0.15645559],
#        [ 0.11543298],
#        [ 0.30257878],
#        [-0.07436404],
#        [ 0.20402843],
#        [-0.01346067],
#        [ 0.1611804 ],
#        [-0.03614138]], dtype=float32)

# %%
loss,rmse,mae=model.evaluate(x_close_test,y_close_test)
# Out:
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0309

# %%
def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0,ylim)
    plt.plot(history.history[metric_name],color='blue',label=metric_name)
    plt.plot(history.history['val_' + metric_name],color='green',label='val_' + metric_name)


plot_metrics(metric_name='loss',title="Loss",ylim=0.02)

# %%
predicted=model.predict(x_close_test)
test_label=y_close_test.reshape(-1,1)
predicted=np.array(predicted[:,0]).reshape(-1,1)
len_train=len(x_close_train)

for j in range(len_train,len_train+len(x_close_test)):
    temp=df.iloc[j,3]
    predicted[j-len_train]=(predicted[j-len_train]+1)*temp
    test_label[j-len_train]=(test_label[j-len_train]+1)*temp
# Out:
# 8/8 [==============================] - 0s 10ms/step

# %%
predicted
# Out:
# array([[133.82419 ],
#        [110.471214],
#        [129.21356 ],
#        [127.94168 ],
#        [125.39892 ],
#        [124.62668 ],
#        [147.98727 ],
#        [100.59008 ],
#        [130.54909 ],
#        [113.27659 ],
#        [119.84097 ],
#        [140.60728 ],
#        [148.93263 ],
#        [147.73744 ],
#        [128.94128 ],
#        [101.9643  ],
#        [159.37936 ],
#        [138.53918 ],
#        [132.034   ],
#        [135.09686 ],
#        [114.334274],
#        [141.32187 ],
#        [126.432495],
#        [110.05888 ],
#        [136.1525  ],
#        [126.82309 ],
#        [141.91649 ],
#        [145.3123  ],
#        [156.60411 ],
#        [107.00587 ],
#        [148.40501 ],
#        [146.95645 ],
#        [125.495895],
#        [131.785   ],
#        [159.26189 ],
#        [144.31863 ],
#        [ 99.67607 ],
#        [111.28201 ],
#        [167.35039 ],
#        [126.625015],
#        [151.03157 ],
#        [101.49265 ],
#        [116.1196  ],
#        [181.14146 ],
#        [136.31155 ],
#        [151.38745 ],
#        [170.76807 ],
#        [165.23402 ],
#        [149.30835 ],
#        [139.12811 ],
#        [131.3525  ],
#        [140.5145  ],
#        [151.24463 ],
#        [137.53458 ],
#        [111.20419 ],
#        [189.30177 ],
#        [147.47643 ],
#        [160.4469  ],
#        [134.91444 ],
#        [145.87564 ],
#        [137.11508 ],
#        [111.25311 ],
#        [121.36742 ],
#        [127.468376],
#        [160.9502  ],
#        [150.81026 ],
#        [136.99414 ],
#        [186.04199 ],
#        [166.93736 ],
#        [158.42754 ],
#        [120.99299 ],
#        [159.64899 ],
#        [176.5164  ],
#        [141.64447 ],
#        [140.68326 ],
#        [174.32362 ],
#        [181.45364 ],
#        [193.29556 ],
#        [160.79358 ],
#        [142.86629 ],
#        [163.395   ],
#        [119.622734],
#        [146.85893 ],
#        [155.34004 ],
#        [199.49292 ],
#        [189.1231  ],
#        [161.53064 ],
#        [120.62507 ],
#        [166.46532 ],
#        [167.85562 ],
#        [153.6768  ],
#        [171.53209 ],
#        [125.35571 ],
#        [130.2151  ],
#        [161.53049 ],
#        [162.31934 ],
#        [134.55743 ],
#        [136.7388  ],
#        [139.2724  ],
#        [132.54155 ],
#        [114.68145 ],
#        [132.16084 ],
#        [142.67706 ],
#        [146.16515 ],
#        [155.48157 ],
#        [152.95714 ],
#        [184.41411 ],
#        [142.83856 ],
#        [132.07585 ],
#        [132.48033 ],
#        [167.24417 ],
#        [170.809   ],
#        [116.16956 ],
#        [121.36812 ],
#        [148.76459 ],
#        [149.30605 ],
#        [173.00822 ],
#        [151.3638  ],
#        [110.86809 ],
#        [113.693726],
#        [145.40671 ],
#        [196.12587 ],
#        [145.03659 ],
#        [145.31032 ],
#        [147.21875 ],
#        [129.77716 ],
#        [162.15503 ],
#        [116.5919  ],
#        [166.49532 ],
#        [167.651   ],
#        [170.25984 ],
#        [190.98091 ],
#        [192.17067 ],
#        [151.93916 ],
#        [148.4513  ],
#        [139.53911 ],
#        [161.1836  ],
#        [175.76869 ],
#        [200.68013 ],
#        [135.0552  ],
#        [189.84306 ],
#        [160.1212  ],
#        [133.93571 ],
#        [184.15733 ],
#        [166.39919 ],
#        [191.7428  ],
#        [146.48828 ],
#        [164.83052 ],
#        [175.09593 ],
#        [175.68645 ],
#        [183.41382 ],
#        [200.46574 ],
#        [177.47781 ],
#        [119.796326],
#        [198.53633 ],
#        [168.91014 ],
#        [143.19994 ],
#        [179.9692  ],
#        [132.8913  ],
#        [137.09103 ],
#        [135.65868 ],
#        [146.12637 ],
#        [132.44275 ],
#        [125.96663 ],
#        [114.50665 ],
#        [181.74696 ],
#        [168.9575  ],
#        [144.75482 ],
#        [154.03564 ],
#        [168.51173 ],
#        [190.32085 ],
#        [150.20927 ],
#        [191.23354 ],
#        [181.7376  ],
#        [168.0423  ],
#        [180.27525 ],
#        [124.79868 ],
#        [137.8669  ],
#        [166.83232 ],
#        [119.129555],
#        [101.1546  ],
#        [140.33437 ],
#        [153.16136 ],
#        [114.553085],
#        [138.49681 ],
#        [137.38127 ],
#        [157.90863 ],
#        [149.40775 ],
#        [132.39014 ],
#        [155.45181 ],
#        [157.7976  ],
#        [152.79465 ],
#        [165.90584 ],
#        [159.85492 ],
#        [147.21071 ],
#        [145.85646 ],
#        [142.11807 ],
#        [115.62594 ],
#        [177.95502 ],
#        [129.46338 ],
#        [143.35172 ],
#        [127.270226],
#        [106.62556 ],
#        [112.61004 ],
#        [130.94424 ],
#        [142.78845 ],
#        [118.64753 ],
#        [184.96523 ],
#        [126.36542 ],
#        [147.03523 ],
#        [172.28024 ],
#        [150.37837 ],
#        [135.23543 ],
#        [176.1707  ],
#        [129.50002 ],
#        [125.24861 ],
#        [174.85252 ],
#        [132.13086 ],
#        [137.03197 ],
#        [126.49779 ],
#        [163.2389  ],
#        [152.8771  ],
#        [128.09692 ],
#        [149.29706 ],
#        [117.95126 ],
#        [158.93135 ],
#        [185.18503 ],
#        [129.23637 ],
#        [167.11552 ],
#        [138.9289  ],
#        [163.66083 ],
#        [131.48776 ]], dtype=float32)

# %%
plt.plot(predicted, color = 'green', label = 'Predicted  Stock Price')
plt.plot(test_label, color = 'red', label = 'Real Stock Price')
plt.title(' Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel(' Stock Price')
plt.legend()
plt.show()
